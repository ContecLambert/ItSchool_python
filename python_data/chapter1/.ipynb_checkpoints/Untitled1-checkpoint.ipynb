# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
y = [1,2,4,2,1]
x = [2,3,4,5,6]

plt.bar(x,y)
plt.show()

# %%
a = np.arange(1.5,7.0)
b = [2,3,3,4,4,4,4,5,5,6]
plt.hist(b,bins =a)
plt.show()

# %%
a = np.arange(1.5,7.0)
b = [2,3,4,5,6]
plt.hist(b,bins =a)
plt.show()
