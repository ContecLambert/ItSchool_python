# %% [markdown]
# Copyright (c) 2019 [윤기태]
#
# https://github.com/yoonkt200/python-data-analysis
#
# [MIT License](https://github.com/yoonkt200/python-data-analysis/blob/master/LICENSE.txt)

# %% [markdown]
# # (가제) 파이썬 데이터 분석

# %% [markdown]
# -----

# %% [markdown]
# # 2.1) 나무위키 최신 변경 문서의 키워드 분석

# %% [markdown]
# ### 바로가기

# %% [markdown]
# - [<Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기](#<Step1.-크롤링>-:-크롤링으로-웹-데이터-가져오기)
#     - [BeautifulSoup을 이용한 웹 크롤링]
#     - [나무위키 최근변경 데이터 크롤링]
# - [<Step2. 추출> : 키워드 추출](#<Step2.-추출>-:-키워드-추출)
#     - [텍스트 데이터 전처리]
#     - [말뭉치 만들기]
#     - [konlpy를 이용한 키워드 추출]
#     - [키워드 가다듬기]
# - [<Step3. 시각화> : 워드 클라우드 시각화](#<Step3.-시각화>-:-워드-클라우드-시각화)
#     - [pytagcloud 사용하기]
#     - [나무위키 키워드 시각화]

# %% [markdown]
# -----

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기

# %% [markdown]
# ### [BeautifulSoup을 이용한 웹 크롤링]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     - (env_name) `pip install requests`
#     - (env_name) `pip install beautifulsoup4`
#     - (env_name) `pip install lxml`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.

# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: requests in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (2.24.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (4.6.0)
# Requirement already satisfied: lxml in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (4.5.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (from requests) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages (from requests) (3.0.4)

# %% [markdown]
# -----

# %% [markdown]
# ##### 페이지 리스트 가져오기

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%EB%A6%AC%EA%B7%B8%EB%82%9C%20%EC%95%84%EC%9D%B4%ED%85%8C%EB%A5%B4%EB%84%88
# https://namu.wiki/w/%EA%B9%80%EC%8B%9C%ED%9B%88
# https://namu.wiki/w/%ED%8B%80:%ED%95%98%EC%8A%A4%EC%8A%A4%ED%86%A4/%EA%B2%AC%EB%B3%B8%20%EB%8D%B1
# https://namu.wiki/w/%EA%B8%88%EA%B0%95(%EC%95%BC%EC%9D%B8%EC%8B%9C%EB%8C%80)
# https://namu.wiki/w/%ED%8B%80:%EC%9C%A0%EB%9F%BD%EC%9D%98%20%EC%A3%BC%EC%9A%94%20%EA%B4%80%ED%98%84%EC%95%85%EB%8B%A8

# %% [markdown]
# -----

# %% [markdown]
# ##### 페이지내 텍스트 구조 확인

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)
# print(type(content_corpus))
print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 리그난 아이테르너
#
#
# 소설 캐릭터군주 캐릭터
#
#
# 린/리그난 아이테르너나이 20세신장 183cm[1]체형 길쭉길쭉 훤칠한 편생일 1월 25일취미 딱히 없음[2]좋아하는 음식 팥앙금 찹쌀떡[3]직업 동부 공작인간 관계 레나 루벨 (친구, 약혼 동맹)  빌 알레스 그라샤 (앙숙)  이우라 플레누스 그라샤 (적대)  루비드 플레누스 그라샤 (적대)  클라비스 시렌치움 그라샤 (적대)  나자 아이테르너 (모친)  데카 모닐 (부하, 비서)머리색 검은색출처1. 개요2. 작중 행적2.1. 황궁 도착 이전2.2. 황궁 도착 당일2.3. 황궁 도착 1일 차2.4. 황궁 도착 2일 차2.5. 황궁 도착 3일 차2.6. 황궁 도착 5일 차2.7. 황궁 도착 6일 차3. 기타"준다면 감사히 받을게. 하지만 보답으로는 과하니까 갚을게. 어떤 식으로든."3화에서 레나가 하룻밤 재워준 보답으로 건넨 제단을 받으며레지나레나 - 용서받지 못한 그대에게에 등장하는 흑발 흑안의 20대 청년. 친절하고 다정한 성격으로 레나가 지나치게 순진무구해서 곤란해하다 레나의 본 모습을 보고 그게 다 연기였냐며 허탈해 한다. 린이라는 이름으로 레나와 통성명했지만 그 정체는 동부 공작 리그난 아이테르너. 제단을 회수하기 위해 위장하고 다녔던 것이다.4대 공작 중 가장 어리며, 유일하게 식민지 출신이라 다른 공작들이 업신여기고 배척한다. 전 동부공 나자 아이테르너의 외아들이지만 사생아이자 식민지 노예의 피가 섞여 그라샤의 칭호를 못 받은 것도 한몫했다. 본래는 공손한 성격이지만 동부를 무시하지 말라는 의미로 다른 공작들에게 찾아가 날뛴다. 그래서 남부공은 린을 '동부의 미친개'라고 부른다.레나를 마음에 들어한다. 밤 산책에서 레나를 만났을 때 동부로 오면 대우하겠다는 제안을 하거나, 자신이 밤 산책을 좋아한다는 말로 또 보고 싶다는 뜻을 드러낸다. 밤이 오면 레나를 만날 수 있다는 생각에 기뻐하기도 한다. 레나의 강하고 부드러운 성격, 뛰어난 실력, 품위 있는 태도를 좋아하는 듯. 더욱이 린은 식민지 출신, 동부 공작 리그난 아이테르너로서의 부담이 있어 레나가 자신을 린으로 대하는 것이 기쁘다.황제의 명령으로 전곳에 흩어진 제단 조각을 찾는 도중 레나 루벨과 유니가 샌드위치를 나눠 먹는 걸 보게 된다. 약자, 특히 여자와 아이에게 비정한 제국에서 그 두 조건에 모두 해당하는 이들이 혼자 있자 걱정스레 지켜보다가 부패한 경비관이 신원을 제시하지 못하는 수상한 사람 취급하며 둘을 데려가자 뒤따라 가고 위기에 처한 둘을 구해주며 첫만남의 매듭을 묶게 된다.안전을 위해 자신이 묵는 여관으로 둘을 데려가 식사를 대접하고 레나에 대해 정보를 알아낸다. 자신을 루벨 후작의 비공식적인 딸이라 소개한 레나가 예정도 잡지 않고 그냥 황궁으로 가는 중이라는 말을 들은 린은 그녀가 매우 순진한 사람이라 생각해서 황궁은 바깥보다 더 잔인한 곳이고 레나가 미인이라 더 타깃으로 삼기 쉬운 사람이라며 집으로 돌아가는 것이 어떠냐고 충고하나 레나는 개의치 않았고 결국 린은 단검 하나를 주면서 만약 자신이 덮치면 망설임 없이 찌르라는 말을 한다. 난생 처음으로 대가 없는 친절이라는 걸 받아본 레나는 린의 이런 태도에 호감이 들어 그에게 예쁘다는 칭찬을 하고, 린은 레나가 약간 모자란 게 아닐까 생각하다 이런 생각을 한 것에 스스로 충격을 받는다.그날 밤 레나가 대가 없는 호의를 처음 받아봤다는 얘기를 듣게 되고 린이 수도로 향하는 거면 데려갈 필요 없다는 소리를 들으며 잠을 청한다. 그러나 레나일행을 공격하려 한 건달 패거리가 숙소까지 쳐들어 오고, 인기척을 느낀 린은 서둘러 레나를 깨운다.[4] 건달들이 문을 부수기 직전, 린은 레나와 아직 잠든 유니를 침대 밑으로 숨기고 그들과 대적한다. 그러나 나한테서 훔쳐간 여자를 내놓으라고 고함을 질러대는 우두머리가 제단을 이용해 사자를 가둔 자 하나를 소환했고, 검집이 망자의 이빨에 의해 박살나자 눈이 진지해지며 전투 태세에 돌입한다.그러나 침대 밑에 있던 레나가 이런 억지와 폭력은 용서받지 못한다며 순진한 착각하지 말고 포기하라며 모습을 드러내고, 망자 때문에 섣불리 움직이지 못한 린은 그녀에게 그만할 것을 부탁한다. 그러나 이미 이성적 판단을 하지 못하는 우두머리는 둘 다 죽으라고 명령했고, 망자는 레나에게 달려든다. 레나가 죽을지도 모른다는 공포감에 린이 뛰쳐나가나...망자가 레나 루벨에게 참수당하고, 그 머리가 곧장 린에게 떨어진다.기겁을 하며 그것을 던진 린은 레나를 멍하니 바라보고 레나가 상황을 다 수습하고, 여태까지 침대 밑에 있던 유니가 건달들의 모든 짐을 갈취하는 광경을 전부 보게 된다.처음부터 두 사람은 여비도 벌고 여자를 함부로 건들지 못하도록 역관광을 목적으로 일부러 끌려가는 척한 것이며 린이 개입하건 안 하건 결과는 다를 것이 없었다는 걸 알게 된 린은 괜한 참견을 했다며 민망해하고 제단을 빼앗을 거냐는 레나의 물음에 왜 전제가 뺏는 거냐고 항의한다.그러자 레나는 미소 지으며 구해줄 필요는 없었지만 친절은 필요했다며 약소한 보답이라며 제단을 건네준다. 차마 이걸 사양할 수 없었던 린은 상단의 대사를 하며 환한 레나의 얼굴을 피한다.날이 밝고 부하들과 합류를 하기로 한 린은 섭섭한 척 하는 레나에게 루벨 후작과 만날 거면 나는 도움이 되지 않는다고 말하고 황궁에서 만나자고 인사를 하며 헤어진다.레나와 헤어진 후 자신의 수하 데카에게 루벨 후작의 딸에 대해 물어보고 죽었다는 소리에 의문스러워 한다. 이후 황궁에 도착해 스스로를 단련하던 중 레나의 행적을 듣고 희한해 한다. 도착하자마자 바로 루벨 후작을 만나러 갔는데, 문전박대했다는 소식을 들어서다. 이미 그녀가 비범한 사람인건 알고 있었지만, 잘 버티기를 마음 속으로 바란다.밤산책을 하던 중 우연히 레나를 만나게 되고, 암살자로 오인한 레나에게 공격당할 뻔한다. 과거 접근하면 단검으로 찌르라는 말을 했던 장본인이었기에 레나의 안전장치를 두고 왔다는 말에 린은 잠시 할 말을 잃는다. 손목을 뻐근하게 만든 걸로도 굳이 검이 없어도 강자임을 입증했기에. 잠옷 차림인 레나에게 제복 외투를 건네준다. 카르도를 만났느냐고 물으면서 정말 병으로 죽은 레나 루벨이냐고 질문한다. 이에 레나가 두 대답 모두 긍정하자 왜 후작을 만나느냐고 묻는다. 그러나 자기 이야기는 하지도 않는다는 점을 지적당하자 묵묵히 자신이 동부인을 고백하며 그녀가 어떤 사람인지 몰랐을 시기에 출신지를 말하면 루벨 가, 즉 북부인이 불편해할 거라 생각했다고 고백한다. 갈 곳 없는 처지에 부친의 숙적과 만났다고 하면 더 곤란해질 것을 걱정한 거였다. 린의 배려를 안 레나는 당황하면서도 솔직하게 이유를 털어놓는다. 그녀의 목적을 들은 린은 제단을 돌려줄 지를 물으나 레나는 부친이 부차적인 것이 아닌 자기 자신만을 받아들여줄 것을 원한다며 거절한다. 그녀의 강인함에 감탄하면서도 예쁘다는 말에 쩔쩔매는 린은 후작이 거부하면 동부로 오라 제안한다. 그러나 계속된 대화로 린의 정체를 알아챈 레나는 다음에는 공작 저하라고 불러야 하냐고 묻고, 너무 빨리 들통난 것에 한숨을 쉰 린은 사람들 앞에선 그래야 한다고 대답한다. 그러나 레나는 이미 남부에 소속된 일원이었기에 그 제안을 거절하고, 대신 린이 오는 게 어떠냐고 제안하고, 그 대범함에 감탄한 린은 고려해보겠다고 답한다. 그렇게 긴 밤산책이 마무리 될 때쯤, 밤산책을 자주 나온다며 은근슬쩍 다시 만날 것을 암시하고, 레나 역시 그에 응한다.공작회담이 개최되지만 린은 초대받지 못한다. 그러나 소식을 전해들은 덕에 세 공작들이 있는 회장에 난입하고 쥐새끼처럼 모여서 작당이나 하고 있는 것이 그라샤의 예의면 마땅히 따라주며 공작들을 쥐새끼라 착각하여 밟아죽이지 않도록 조심하겠다는 모욕을 날리고, 북부공과 남부공의 심기를 제대로 상하게 만든다.[5] 그러나 이건 모두 연기로 무시당해 소외되는 것보다는 망나니처럼 보여 미움받는 것이 낫다는 판단 하에 행하는 일이었다. 본디 그는 동부보다 더 동쪽에 위치한 성품이 온화하고 예의를 지키는 일족이었기에 자기보다 한참 어른인 남부공에게 쥐새끼라 표현한 걸 나름 씁쓸해하고 있었다. 그날 밤에 다시 레나를 만날 것을 기대하며 스트레스를 낮추는 도중 데카에게서 남부공 빌 알레스가 그녀를 초대한 걸 알고 바로 외로워진다 ...

# %% [markdown]
# -----

# %% [markdown]
# ### [나무위키 최근변경 데이터 크롤링]

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#             title                           category  \
# 0      리그난 아이테르너                        소설 캐릭터군주 캐릭터
# 1            김시훈   대한민국의 배구 선수1987년 출생개명한 인물인하대학교 출신
# 2    틀:하스스톤/견본 덱                       둘러보기 틀/게임하스스톤
# 3       금강(야인시대)            야인시대/등장인물반동인물/야인시대페이크 빌런
# 4  틀:유럽의 주요 관현악단                         고전 음악 연주 단체
#
#                                         content_text
# 0  린/리그난 아이테르너나이 20세신장 183cm[1]체형 길쭉길쭉 훤칠한 편생일 1월...
# 1     은(는) 여기로 연결됩니다. NC 다이노스 소속 1999년생 야구선수에 대한 ...
# 2  하스스톤 견본 덱전사주술사도적성기사사냥꾼클래식 전사클래식 주술사클래식 도적클래식 성...
# 3  공산당  [ 펼치기 · 접기 ]당수박헌영조선청년전위대김두한(탈퇴) → 정진영신불출김...
# 4  유럽의 주요 관현악단  [ 펼치기 · 접기 ] BBC 교향악단  드레스덴 국립 관현...

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
해달라는 신호인 것 처음에 뭔가 있어보이는 분위기를 실컷 자아내는가 싶더니 알고보니 그게 다 자기랑 놀아달라고 응석 부리는 것이었다 이 무슨 갭모에가이후 쥬다는 과거를 회상하는데 사실 쥬다는 단순한 제국군 장교 정도가 아니라 황제의 오른팔  개국 공신이었다 그런데 고작 군단 대령에 불과하냐 과거 멍때리고 있던 쥬다에게 한 아이가 접근에 어떤 뼈를 집어던졌고 거기에 맞아 열뻗친 쥬다는 늑대 모드로 변신해 아이를 잡아죽이러 추적했지만 불가사의한 스피드로 도망치는 그 아이를 잡지 못하다 며칠간의 추격전 끝에 겨우 잡는다 드디어 아이를 붙잡아 기쁨에 찬 쥬다에게 붙잡힌 그 아이는 태연하게 자신이 며칠전 집어던진 뼈는 기억하고 있냐는 뜬금없는 질문을 하는데 알고보니 그 뼈는 며칠전즉 쥬다와 처음 만난 날 그 아이가 누군가에게 시비를 걸었다가 얻어맞아서 자기몸에서 튀어나온 그 아이 자신의 쇄골뼈라는 것 이후 그 아이는 쥬다에게 자신이 제국을 세울 것이라는 포부를 밝히는 것으로 회상이 종료된다이후 쥬다는 꿈을 꾸는데 사실 정확히는 단순한 꿈이 아니라 계시를 받는 것으로 그 내용은 쥬다 자신의 본체이기도 한 세계의 아집이 세계를 멸망시킬것을 지시하는 것이었다 쥬다는 필사적으로 이를 거부하는데 이 때 현실에서 쥬다가 괴로워하는 모습을 본 주인공은 룬 파워를 발사했고 빛의 영향을 받은 쥬다는 자신은 어디까지나 황제의 충신이기 때문에 세계를 파괴하는 것 즉 황제와 제국을 파괴하는 짓은 절대로 할 수 없다며 세계의 아집에게 반역을 선포했다 세계의 아집은 쥬다의 선언 또한 아집이며 쥬다가 본체인 자신과 별개의 아집을 찾아내고 집착한다는 걸 재미있어하며 쥬다에게서 손을 뗀다 이후 정신을 차려 다시 현실로 돌아온 쥬다는 주인공 일행의 도움에 감사하며 마무리된다소오나 종결 이후로 년하고도 몇 달이 지나서야 쥬다가 주인공으로 재등장한 이벤트 소오나에서는 두루뭉술하게만 나온 제국의 관이라던가 황제라던가 하는 떡밥들을 본격적으로 회수하며 동시에 그동안 개인 스토리 외에는 초연적으로 그려졌던 쥬다의 고뇌와 본질에도 근접하는 이야기이기도 하다안그래도 소오나 시 ...

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#            title                       category  \
# 0     리그난 아이테르너                    소설 캐릭터군주 캐릭터
# 1           김시훈   대한민국의 배구 선수년 출생개명한 인물인하대학교 출신
# 2     틀하스스톤견본 덱                    둘러보기 틀게임하스스톤
# 3        금강야인시대          야인시대등장인물반동인물야인시대페이크 빌런
# 4  틀유럽의 주요 관현악단                     고전 음악 연주 단체
#
#                                         content_text
# 0  린리그난 아이테르너나이 세신장 체형 길쭉길쭉 훤칠한 편생일 월 일취미 딱히 없음좋아...
# 1    은는 여기로 연결됩니다  다이노스 소속 년생 야구선수에 대한 내용은 김시훈야구선...
# 2  하스스톤 견본 덱전사주술사도적성기사사냥꾼클래식 전사클래식 주술사클래식 도적클래식 성...
# 3  공산당   펼치기  접기 당수박헌영조선청년전위대김두한탈퇴  정진영신불출김천호김해숙배...
# 4  유럽의 주요 관현악단   펼치기  접기   교향악단  드레스덴 국립 관현악단 라 스...

# %% [markdown]
# -----

# %% [markdown]
# ### [말뭉치 만들기]

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 리그난 아이테르너 김시훈 틀하스스톤견본 덱 금강야인시대 틀유럽의 주요 관현악단 에너지 스테로이드  요즘 유행하는 인사법  스토브리그 개 곽상도논란 보스턴 다이내믹스 박시후  서번트엑스트라 클래스포리너애비게일 윌리엄스여름 김광국배구선수 사생활드라마 김기명 애인 있어요 안은진배우  우회 방법 코드네임 시리즈 박진우배구선수 바람불어 좋은 날 박상민 신들의 만찬 신서유기에피소드  년 건프라목록 일해회 카운터사이드평가 북산 년 브라질 지방선거여론조사   크루세이더 미친 사랑 리그 오브 레전드아이템전설 레지나레나  용서받지 못한 그대에게 유우삼국지 리그 오브 레전드 시즌 있을 때 잘해 미주리 바니걸 진술거부권 송지효 아틀레티코 마드리드 놋치 홍종선    컴투스 프로야구  매니저팀덱 투석기워크래프트 시리즈 청주대학교 산악부 쿠키런 오븐브레이크쿠키 데스노트애니메이션 광삼패   영남중학교부산 태양의 신부 우아한 친구들 년 미국 대통령 선거 서울 버스  그래도 좋아 이은채미니리치걸 큐비스타  리그년신인드래프트 요아힘 뢰프    모드      국가 페드로 마르티네스 신기생뎐드라마 김원석야구선수 이용진 유수빈 시그룬 엥겔 최성훈프로게이머 헤드크랩 세상에서 제일 예쁜 내 딸 원펀맨 어 히어로 노바디 노우즈 보우마스터 파일안페범죄 나무집 시리즈각 권 등장인물 바나나는 원래 하얗다 도널드 럼즈펠드 김정은

# %% [markdown]
# -----

# %% [markdown]
# ### [konlpy를 이용한 키워드 추출]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
# - 아래의 방법으로 설치해도 실행되지 않는다면, http://konlpy.org/ko/latest/install/ 를 참고하세요.
#     - Install
#         - 1. Java를 설치합니다. (https://java.com/ko/download/)
#         - 2. c++ 컴파일러를 설치합니다.
#             - 윈도우 : `Microsoft Visual C++ 14.0` 설치 권장, https://visualstudio.microsoft.com/ko/downloads/
#             - Mac OS : `Xcode` 설치 권장
#             - Linux : `gcc` 설치 권장
#         - 3. 아래와 같은 파이썬 패키지를 설치합니다. **konlpy 버전을 반드시 0.5.1로 해주어야 합니다. 2020년 현재(9월) 기준, 최신 버전 konlpy 에서는 일부 개발환경에서 자바 에러가 발생합니다.**
#             - (env_name) `pip install konlpy==0.5.1`
#             - (env_name) `pip install jpype1`
#             - (env_name) `pip install Jpype1-py3`

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

# %%
count
# Out:
# Counter({'린': 114,
#          '리그': 311,
#          '아이테르': 20,
#          '나이': 74,
#          '신장': 12,
#          '체형': 10,
#          '훤칠': 1,
#          '편': 147,
#          '생일': 34,
#          '월': 1664,
#          '취미': 12,
#          '음식': 76,
#          '팥': 2,
#          '앙금': 2,
#          '찹쌀떡': 2,
#          '직업': 65,
#          '동부': 40,
#          '공작': 31,
#          '인간': 202,
#          '관계': 120,
#          '레나': 208,
#          '루벨': 39,
#          '친구': 102,
#          '약혼': 10,
#          '동맹': 33,
#          '알레스': 9,
#          '그라샤': 40,
#          '앙숙': 6,
#          '이우': 8,
#          '플레누스': 8,
#          '적대': 10,
#          '루비': 9,
#          '드': 43,
#          '클라비스': 21,
#          '시렌': 6,
#          '너': 85,
#          '모친': 3,
#          '데카': 5,
#          '모닐': 1,
#          '부하': 34,
#          '비서': 17,
#          '머리색': 4,
#          '검은색': 3,
#          '출처': 35,
#          '개요': 65,
#          '중': 718,
#          '행적': 16,
#          '황궁': 18,
#          '도착': 79,
#          '이전': 1097,
#          '당일': 22,
#          '일': 1146,
#          '차': 202,
#          '기타': 105,
#          '보답': 4,
#          '과': 44,
#          '식': 70,
#          '화': 185,
#          '하룻밤': 3,
#          '준': 92,
#          '제단': 18,
#          '레지나': 9,
#          '용서': 19,
#          '못': 311,
#          '그대': 17,
#          '등장': 209,
#          '흑발': 3,
#          '안': 439,
#          '청년': 16,
#          '성격': 57,
#          '순진무구': 1,
#          '모습': 355,
#          '보고': 166,
#          '그게': 31,
#          '연기': 70,
#          '며': 40,
#          '이름': 244,
#          '통성명': 1,
#          '그': 1209,
#          '정체': 39,
#          '회수': 16,
#          '위해': 309,
#          '위장': 12,
#          '것': 2210,
#          '다대': 4,
#          '가장': 264,
#          '식민지': 16,
#          '출신': 115,
#          '다른': 424,
#          '여기': 154,
#          '배척': 1,
#          '전': 456,
#          '부공': 14,
#          '외아들': 3,
#          '사생아': 2,
#          '이자': 121,
#          '노예': 10,
#          '피': 160,
#          '칭호': 8,
#          '한몫': 7,
#          '본래': 31,
#          '무시': 57,
#          '말': 777,
#          '의미': 81,
#          '남부': 85,
#          '공': 77,
#          '개': 568,
#          '마음': 97,
#          '밤': 64,
#          '산책': 7,
#          '때': 833,
#          '대우': 8,
#          '제안': 58,
#          '거나': 93,
#          '자신': 476,
#          '말로': 10,
#          '또': 149,
#          '뜻': 48,
#          '만날': 10,
#          '수': 1132,
#          '생각': 256,
#          '기도': 115,
#          '실력': 83,
#          '품위': 2,
#          '태도': 35,
#          '듯': 206,
#          '더욱이': 2,
#          '로서': 93,
#          '부담': 16,
#          '대하': 21,
#          '황제': 60,
#          '명령': 36,
#          '곳': 149,
#          '조각': 7,
#          '도중': 55,
#          '유니': 7,
#          '샌드위치': 11,
#          '걸': 283,
#          '약자': 10,
#          '여자': 74,
#          '아이': 68,
#          '제국': 58,
#          '두': 196,
#          '조건': 66,
#          '모두': 317,
#          '해당': 169,
#          '이': 1266,
#          '혼자': 52,
#          '걱정': 27,
#          '스레': 2,
#          '비관': 8,
#          '신원': 2,
#          '제시': 29,
#          '수상한': 17,
#          '사람': 481,
#          '취급': 48,
#          '둘': 117,
#          '위기': 43,
#          '처': 42,
#          '구': 91,
#          '만남': 11,
#          '매듭': 2,
#          '여관': 1,
#          '식사': 50,
#          '대접': 3,
#          '대해': 192,
#          '정보': 99,
#          '후작': 13,
#          '비공식': 9,
#          '딸': 90,
#          '소개': 50,
#          '예정': 84,
#          '잡지': 15,
#          '그냥': 119,
#          '중이': 47,
#          '그녀': 49,
#          '매우': 177,
#          '바깥': 8,
#          '더': 460,
#          '미인': 4,
#          '타깃': 4,
#          '집': 178,
#          '충고': 6,
#          '하나': 333,
#          '의치': 5,
#          '단검': 26,
#          '만약': 61,
#          '난생': 1,
#          '처음': 181,
#          '대가': 34,
#          '친절': 4,
#          '호감': 13,
#          '칭찬': 22,
#          '약간': 34,
#          '게': 197,
#          '스스로': 44,
#          '충격': 59,
#          '그날': 10,
#          '호의': 6,
#          '얘기': 37,
#          '수도': 131,
#          '향': 45,
#          '거': 246,
#          '필요': 33,
#          '소리': 111,
#          '잠': 35,
#          '청': 22,
#          '일행': 26,
#          '공격': 627,
#          '건달': 6,
#          '패거리': 5,
#          '숙소': 54,
#          '인기척': 1,
#          '문': 49,
#          '부': 138,
#          '수기': 3,
#          '직전': 36,
#          '침대': 16,
#          '밑': 37,
#          '숨기': 13,
#          '대적': 8,
#          '나': 275,
#          '간': 64,
#          '고함': 2,
#          '우두머리': 6,
#          '이용': 111,
#          '사자': 12,
#          '자': 62,
#          '소환': 42,
#          '검집': 1,
#          '망': 44,
#          '이빨': 12,
#          '박살': 15,
#          '눈': 86,
#          '전투': 95,
#          '태세': 5,
#          '돌입': 11,
#          '억지': 5,
#          '폭력': 17,
#          '착각': 15,
#          '포기': 59,
#          '하라': 29,
#          '때문': 784,
#          '섣불리': 5,
#          '움직': 6,
#          '부탁': 30,
#          '성적': 96,
#          '판단': 25,
#          '공포': 29,
#          '감': 51,
#          '참수': 6,
#          '머리': 119,
#          '곧장': 1,
#          '기겁': 4,
#          '그것': 63,
#          '멍하니': 2,
#          '상황': 309,
#          '수습': 7,
#          '여태': 6,
#          '모든': 198,
#          '짐': 15,
#          '갈취': 3,
#          '광경': 10,
#          '전부': 67,
#          '여비': 1,
#          '함부로': 6,
#          '건': 195,
#          '역': 120,
#          '관광': 11,
#          '목적': 37,
#          '일부러': 17,
#          '척': 35,
#          '개입': 22,
#          '결과': 156,
#          '알': 293,
#          '괜': 2,
#          '참견': 4,
#          '물음': 4,
#          '왜': 70,
#          '전제': 7,
#          '고': 58,
#          '항의': 14,
#          '미소': 6,
#          '약소': 2,
#          '차마': 6,
#          '사양': 6,
#          '상단': 9,
#          '대사': 63,
#          '얼굴': 81,
#          '다날': 1,
#          '합류': 34,
#          '도움': 66,
#          '인사': 52,
#          '후': 393,
#          '수하': 2,
#          '의문': 54,
#          '이후': 693,
#          '자마자': 21,
#          '바로': 166,
#          '박대': 2,
#          '소식': 38,
#          '사람인': 5,
#          '속': 150,
#          '암살자': 28,
#          '오인': 6,
#          '과거': 133,
#          '접근': 22,
#          '장본인': 10,
#          '안전': 9,
#          '장치': 18,
#          '잠시': 53,
#          '손목': 5,
#          '도': 160,
#          '굳이': 25,
#          '검': 104,
#          '강': 233,
#          '자임': 2,
#          '입증': 3,
#          '잠옷': 3,
#          '차림': 8,
#          '제복': 5,
#          '외투': 2,
#          '카르': 6,
#          '정말': 53,
#          '병': 51,
#          '질문': 34,
#          '대답': 46,
#          '긍정': 21,
#          '자기': 124,
#          '이야기': 135,
#          '점': 316,
#          '지적': 25,
#          '부인': 31,
#          '고백': 11,
#          '시기': 48,
#          '즉': 108,
#          '북부': 30,
#          '처지': 9,
#          '부친': 7,
#          '숙적': 2,
#          '배려': 20,
#          '당황': 37,
#          '이유': 167,
#          '부차': 1,
#          '거절': 29,
#          '감탄': 6,
#          '거부': 53,
#          '오라': 6,
#          '계속': 180,
#          '대화': 45,
#          '다음': 271,
#          '저하': 7,
#          '들통': 5,
#          '한숨': 1,
#          '쉰': 2,
#          '앞': 134,
#          '래야': 4,
#          '소속': 129,
#          '일원': 11,
#          '대신': 181,
#          '고려': 40,
#          '답': 64,
#          '마무리': 51,
#          '자주': 96,
#          '은근': 25,
#          '다시': 275,
#          '암시': 11,
#          '역시': 187,
#          '응': 18,
#          '회담': 13,
#          '개최': 22,
#          '초대': 37,
#          '전해': 6,
#          '덕': 32,
#          '세': 188,
#          '회장': 76,
#          '난입': 6,
#          '쥐': 16,
#          '새끼': 22,
#          '모': 22,
#          '작당': 1,
#          '예의': 11,
#          '죽': 44,
#          '모욕': 12,
#          '공과': 6,
#          '심기': 2,
#          '제대로': 97,
#          '상하': 10,
#          '이건': 46,
#          '소외': 1,
#          '망나니': 7,
#          '미움': 7,
#          '낫다': 18,
#          '하': 12,
#          '행': 33,
#          '본디': 3,
#          '동쪽': 6,
#          '위치': 62,
#          '성품': 4,
#          '족': 13,
#          '한참': 21,
#          '어른': 8,
#          '표현': 59,
#          '나름': 34,
#          '스트레스': 5,
#          '귀족': 12,
#          '영애': 4,
#          '귀빈': 2,
#          '천치차이': 1,
#          '작별인사': 2,
#          '정원': 6,
#          '호숫가': 1,
#          '권능': 23,
#          '파장': 10,
#          '방향': 18,
#          '확인': 78,
#          '범인': 48,
#          '샤인': 1,
#          '확신': 11,
#          '언제': 34,
#          '대기': 91,
#          '마침내': 18,
#          '겉옷': 2,
#          '손님': 7,
#          '작별': 2,
#          '세간': 5,
#          '최고': 157,
#          '사이': 161,
#          '최악': 31,
#          '개자식': 3,
#          '입장': 83,
#          '몇': 60,
#          '번': 1318,
#          '적': 284,
#          '일전': 4,
#          '방식': 71,
#          '심야': 3,
#          '지속': 197,
#          '하자': 72,
#          '외적인': 3,
#          '서로': 78,
#          '우정': 9,
#          '약속': 31,
#          '추가': 326,
#          '본인': 168,
#          '뒤': 292,
#          '뜬금': 4,
#          '무슨': 46,
#          '연애': 12,
#          '감정': 27,
#          '진심': 15,
#          '의': 725,
#          '의심': 58,
#          '시간': 400,
#          '허락': 15,
#          '꽃': 24,
#          '건국기념일': 1,
#          '아침': 81,
#          '대례전': 4,
#          '등': 871,
#          '흉내': 4,
#          '오후': 20,
#          '일정': 41,
#          '무더기': 5,
#          '행패': 4,
#          '온': 97,
#          '비교': 122,
#          '정도': 439,
#          '지옥': 20,
#          '처리': 43,
#          '공이': 10,
#          '무': 83,
#          '감사': 6,
#          '옆': 77,
#          '보아': 26,
#          '시비': 6,
#          '루비드': 8,
#          '평소': 23,
#          '말다툼': 3,
#          '찰나': 10,
#          '은혜': 4,
#          '보은': 1,
#          '가로막': 1,
#          '덕분': 71,
#          '언쟁': 1,
#          '피하': 15,
#          '기사': 123,
#          '무덤': 39,
#          '사하나': 1,
#          '존재': 120,
#          '체계': 12,
#          '성의': 6,
#          '구조': 21,
#          '전략': 42,
#          '고민': 37,
#          '지휘': 32,
#          '관': 60,
#          '만찬': 14,
#          '연락': 14,
#          '폭행': 13,
#          '소문': 16,
#          '묘': 19,
#          '우려': 18,
#          '기사단': 5,
#          '울음': 13,
#          '토벌': 12,
#          '선봉': 4,
#          '달라': 79,
#          '요구': 65,
#          '현실': 88,
#          '분간': 5,
#          '고집': 6,
#          '긴장': 10,
#          '조금': 63,
#          '원정': 39,
#          '이틀': 12,
#          '함정': 8,
#          '선택': 177,
#          '왕': 139,
#          '테': 40,
#          '수칙': 1,
#          '성': 29,
#          '전리품': 2,
#          '가지': 193,
#          '날': 175,
#          '동남': 4,
#          '곧이곧대로': 1,
#          '진로': 1,
#          '종이': 35,
#          '화살': 36,
#          '쪽': 109,
#          '틈': 12,
#          '타': 197,
#          '지대': 10,
#          '진': 205,
#          '전방': 10,
#          '감시': 13,
#          '열흘': 2,
#          '귀환': 10,
#          '본성': 3,
#          '퇴각': 1,
#          '명의': 69,
#          '명': 502,
#          '동행': 5,
#          '일곱': 4,
#          '식량': 9,
#          '나머지': 64,
#          '소금': 9,
#          '사흘': 2,
#          '주일': 7,
#          '양': 46,
#          '보물': 9,
#          '수거': 1,
#          '선방': 4,
#          '과정': 78,
#          '칠': 24,
#          '생리': 2,
#          '현상': 45,
#          '능률': 1,
#          '점점': 46,
#          '간다': 42,
#          '질식': 4,
#          '느낌': 37,
#          '사망': 94,
#          '죽음': 54,
#          '분노': 32,
#          '보고서': 5,
#          '정의': 17,
#          '만난': 17,
#          '놀란': 9,
#          '상태': 249,
#          '행보': 24,
#          '설명': 109,
#          '놀림': 6,
#          '함락': 5,
#          '방법': 77,
#          '위': 495,
#          '제의': 22,
#          '서도': 17,
#          '강하': 4,
#          '최선': 11,
#          '어디': 46,
#          '도울': 3,
#          '사정': 25,
#          '반려': 4,
#          '정벌': 5,
#          '순간': 72,
#          '파혼': 1,
#          '홀로': 18,
#          '몸부림': 2,
#          '달빛': 10,
#          '아래': 54,
#          '마리': 25,
#          '유교': 4,
#          '맨': 58,
#          '비즈니스': 2,
#          '안도': 1,
#          '라면': 109,
#          '핑계': 10,
#          '대고': 8,
#          '분명': 22,
#          '결렬': 2,
#          '뿐': 105,
#          '어째서': 4,
#          '기분': 23,
#          '새우': 4,
#          '복도': 4,
#          '시선': 16,
#          '거두': 2,
#          '호통': 1,
#          '무척': 12,
#          '조롱': 10,
#          '싸움': 68,
#          '중재': 5,
#          '눈빛': 8,
#          '내심': 6,
#          '상처': 39,
#          '승': 90,
#          '주인': 68,
#          '욕하자': 1,
#          '반역죄': 2,
#          '처벌': 17,
#          '가치': 20,
#          '증명': 20,
#          '대결': 52,
#          '상대로': 54,
#          '아들': 99,
#          '지명': 112,
#          '잡': 22,
#          '농담': 13,
#          '최대한': 17,
#          '바닥': 17,
#          '유인': 11,
#          '형세': 1,
#          '팔': 35,
#          '집중': 44,
#          '칼': 50,
#          '힘': 112,
#          '충돌': 23,
#          '의도': 48,
#          '방어': 141,
#          '일관': 9,
#          '린다': 16,
#          '크게': 105,
#          '이기': 119,
#          '판결': 3,
#          '반역': 9,
#          '생기': 10,
#          '안부': 2,
#          '단': 111,
#          '정신병': 3,
#          '처형': 40,
#          '강박': 4,
#          '언급': 121,
#          '사실': 344,
#          '경우': 488,
#          '성욕': 3,
#          '돌변': 5,
#          '물': 92,
#          '파괴': 31,
#          '심지어': 86,
#          '꼬': 6,
#          '변': 15,
#          '당한': 14,
#          '시작': 380,
#          '수십': 7,
#          '역대': 112,
#          '문제': 363,
#          '안고': 8,
#          '산': 72,
#          '독신': 5,
#          '결심': 10,
#          '첫': 195,
#          '밀회': 1,
#          '눈길': 3,
#          '통해': 138,
#          '기간': 71,
#          '동안': 222,
#          '이익': 6,
#          '어차피': 25,
#          '사랑': 124,
#          '수가': 60,
#          '몸': 74,
#          '세상': 49,
#          '남아': 21,
#          '이서': 8,
#          '바랬': 1,
#          '연정': 2,
#          '억': 55,
#          '다화': 19,
#          '천하': 12,
#          '불한당': 1,
#          '잠깐': 29,
#          '정심': 5,
#          '결혼': 53,
#          '당시': 208,
#          '성년': 5,
#          '전쟁': 138,
#          '참전': 20,
#          '전의': 21,
#          '시점': 75,
#          '그때': 49,
#          '벼랑': 1,
#          '끝': 155,
#          '구혼': 2,
#          '자존심': 7,
#          '상': 69,
#          '뿐더러': 7,
#          '부작용': 13,
#          '살인마': 1,
#          '최근': 56,
#          '통치': 26,
#          '무엇': 40,
#          '습격': 5,
#          '제일': 82,
#          '먼저': 126,
#          '지원': 167,
#          '종결': 7,
#          '희망': 15,
#          '하니': 16,
#          '재수': 6,
#          '나기': 2,
#          '아주': 44,
#          '바르게': 1,
#          '그동안': 25,
#          '유지': 116,
#          '캐릭터': 251,
#          '관심': 53,
#          '독설': 4,
#          '문서': 1161,
#          '사건': 254,
#          '다린': 1,
#          '민족': 31,
#          '묘사': 36,
#          '안이': 6,
#          '우리': 227,
#          '년': 1894,
#          '난': 64,
#          '혼인': 1,
#          '영원': 5,
#          '한국': 158,
#          '마냥': 21,
#          '치부': 3,
#          '의견': 54,
#          '게다가': 91,
#          '조국': 10,
#          '동방': 5,
#          '설': 38,
#          '보태': 1,
#          '본명': 16,
#          '난이': 2,
#          '리': 120,
#          '영': 38,
#          '은': 126,
#          '연결': 31,
#          '다이노스': 8,
#          '년생': 22,
#          '야구선수': 27,
#          '대한': 423,
#          '내용': 354,
#          '김시': 15,
#          '훈': 27,
#          '를': 463,
#          '문단': 1274,
#          '부분': 275,
#          '가수': 65,
#          '참조': 77,
#          '대전': 43,
#          '삼성': 45,
#          '화재': 21,
#          '블루': 21,
#          '팡스': 6,
#          '시즌': 772,
#          '선수단': 25,
#          '접기': 117,
#          '코칭스태프': 8,
#          '감독': 338,
#          '고희진': 2,
#          '코치': 111,
#          '김영': 4,
#          '윤': 24,
#          '세운': 23,
#          '이강주': 3,
#          '스태프': 42,
#          '이승윤': 2,
#          '은상': 2,
#          '김': 72,
#          '연석': 2,
#          '김철홍': 2,
#          '이선': 8,
#          '엽': 3,
#          '이용우': 2,
#          '태일': 2,
#          '레프트': 8,
#          '김우진': 2,
#          '준용': 2,
#          '장호': 8,
#          '황경민': 4,
#          '이하늘': 2,
#          '정성규': 2,
#          '김인혁': 5,
#          '이현승': 2,
#          '라이트': 13,
#          '김동영': 2,
#          '텍': 4,
#          '센터': 49,
#          '엄윤식': 3,
#          '박상': 9,
#          '김정윤': 3,
#          '태환': 5,
#          '세터': 24,
#          '이승원': 5,
#          '정승현': 3,
#          '리베로': 7,
#          '지석': 2,
#          '박지훈': 3,
#          '군입': 3,
#          '대년': 2,
#          '입대': 42,
#          '안우': 3,
#          '재': 73,
#          '이강원': 2,
#          '노재욱': 12,
#          '손태': 2,
#          '생년': 11,
#          '월일년': 1,
#          '국적': 15,
#          '대한민국': 176,
#          '학력': 16,
#          '각초': 1,
#          '광주': 17,
#          '흥': 26,
#          '자공고': 1,
#          '인하대': 5,
#          '포지션': 48,
#          '신체': 30,
#          '배구': 10,
#          '입문': 6,
#          '중학교': 50,
#          '학년': 82,
#          '프로': 51,
#          '입단': 27,
#          '라운드': 127,
#          '순위': 47,
#          '캐피탈': 11,
#          '구단': 66,
#          '서울': 73,
#          '드림식스': 13,
#          '우리카드': 34,
#          '위비': 4,
#          '군복무': 5,
#          '상무': 13,
#          '응원가': 11,
#          '시절': 159,
#          '런닝맨': 45,
#          '오프닝': 12,
#          '주제가': 9,
#          '최후': 39,
#          '인': 89,
#          '훈김': 2,
#          '광국': 3,
#          '블루팡스': 1,
#          '선수': 392,
#          '원래': 118,
#          '김태진': 1,
#          '전역': 35,
#          '김시훈': 4,
#          '개명': 2,
#          '교체': 40,
#          '활약': 97,
#          '드래프트': 27,
#          '동기': 14,
#          '김광국': 24,
#          '승승장구': 1,
#          '지금': 127,
#          '비': 174,
#          '씨름': 4,
#          '이적': 52,
#          '박진우': 17,
#          '군입대': 4,
#          '주전': 46,
#          '후보': 131,
#          '경쟁': 29,
#          '백업': 19,
#          '출장': 18,
#          '윤봉우': 4,
#          '구도현': 5,
#          '각각': 80,
#          '부상': 81,
#          '부진': 17,
#          '경기': 288,
#          '이제': 89,
#          '가운데': 19,
#          '갑자기': 63,
#          '속공': 15,
#          '여러': 106,
#          '교차': 5,
#          '허리': 6,
#          '김상우': 6,
#          '중용': 2,
#          '사용': 316,
#          '호흡': 6,
#          '손해': 18,
#          '보험': 13,
#          '커리어': 22,
#          '최': 98,
#          '다득점': 4,
#          '득점': 35,
#          '다년': 168,
#          '승리': 127,
#          '확정': 87,
#          '갱신': 12,
#          '꽤': 92,
#          '플레이오프': 10,
#          '무참': 1,
#          '와중': 71,
#          '세트': 58,
#          '팬': 168,
#          '김정환': 4,
#          '팀': 683,
#          '안준': 1,
#          '찬': 13,
#          '은퇴': 51,
#          '마지막': 239,
#          '멤버': 298,
#          '신영석': 4,
#          '빛': 31,
#          '보지': 25,
#          '입': 112,
#          '하현': 2,
#          '용': 101,
#          '최석기': 1,
#          '황': 15,
#          '코로나바이러스': 98,
#          '감염증': 94,
#          '확산': 52,
#          '여파': 23,
#          '조기': 8,
#          '종료': 200,
#          '경기도': 17,
#          '류윤식': 3,
#          '송희채': 2,
#          '호건': 2,
#          '초대형': 6,
#          '트레이드': 26,
#          '잔': 28,
#          '손태훈': 1,
#          '경험': 29,
#          '기회': 68,
#          '다변': 2,
#          '높이': 11,
#          '저': 96,
#          '멀리': 25,
#          '하늘': 32,
#          '하스스톤': 2,
#          '견본': 1,
#          '덱': 10,
#          '주술사': 2,
#          '도적': 8,
#          '성기사': 2,
#          '사냥꾼': 6,
#          '클래식': 27,
#          '전사': 45,
#          '해적': 20,
#          '토템': 4,
#          '과부': 1,
#          '날붙이': 1,
#          '리아': 6,
#          '성서': 2,
#          '땐': 18,
#          '명치': 1,
#          '타락': 7,
#          '비밀': 36,
#          '심연': 12,
#          '쿠당탕': 1,
#          '통통': 3,
#          '전차': 12,
#          '드루이드': 2,
#          '흑마': 4,
#          '법사': 8,
#          '마법사': 35,
#          '사제': 2,
#          '악마': 28,
#          '적자생존': 1,
#          '작': 63,
#          '마법': 212,
#          '다크': 16,
#          '동물원': 5,
#          '쇄도': 4,
#          '주문': 190,
#          '시전': 17,
#          '대회': 97,
#          '리시아': 1,
#          '악의': 10,
#          '위즈': 4,
#          '뱅': 4,
#          '님': 1,
#          '공산당': 23,
#          '박헌영': 6,
#          '조선청년전위대': 2,
#          ...})

# %% [markdown]
# -----

# %% [markdown]
# ### [키워드 가다듬기]

# %% [markdown]
# ##### 한글자 키워드 제거

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'문단': 1274, '문서': 1161, '이전': 1097, '역사': 1043, '때문': 784, '시즌': 772, '이후': 693, '공격': 627, '쿠키': 624, '효과': 521, '강호동': 491, '경우': 488, '게임': 484, '사람': 481, '자신': 476, '아이템': 462, '정도': 439, '토론': 434, '합의': 430, '다른': 424, '대한': 423, '이수근': 416, '은지원': 415, '사항': 413, '시간': 400, '선수': 392, '시작': 380, '미국': 380, '문제': 363, '피해': 362, '모습': 355, '내용': 354, '사실': 344, '피오': 339, '감독': 338, '하나': 333, '미션': 333, '추가': 326, '스킬': 325, '기록': 324, '체력': 323, '챔피언': 320, '모두': 317, '사용': 316, '또한': 316, '리그': 311, '국가': 310, '위해': 309, '상황': 309, '규현': 308, '송민호': 301, '멤버': 298, '경기': 288, '김정은': 282, '다시': 275, '부분': 275, '페드로': 272, '다음': 271, '가장': 264, '이상': 264, '대통령': 257, '생각': 256, '사건': 254, '캐릭터': 251, '드라마': 251, '상태': 249, '이름': 244, '마지막': 239, '기본': 239, '가격': 231, '우리': 227, '적용': 224, '동안': 222, '능력': 222, '인물': 220, '상대': 219, '투수': 216, '관련': 213, '마법': 212, '등장': 209, '패치': 209, '호동': 209, '레나': 208, '당시': 208, '속도': 208, '안재현': 208, '현재': 207, '자체': 206, '인간': 202, '종료': 200, '모든': 198, '지속': 197, '가지': 193, '중국': 193, '계약': 193, '대해': 192, '출연': 192, '방송': 192, '주문': 190, '일월': 190, '역시': 187, '처음': 181, '대신': 181, '계속': 180, '독일': 180, '북한': 179, '민호': 178, '매우': 177, '선택': 177, '대한민국': 176, '조합': 175, '거의': 170, '진행': 170, '해당': 169, '본인': 168, '다년': 168, '이유': 167, '지원': 167, '바이든': 167, '이닝': 167, '보고': 166, '바로': 
 77, '행동': 77, '조사': 77, '출시': 77, '분장': 77, '음식': 76, '회장': 76, '최종': 76, '시점': 75, '초반': 75, '진짜': 75, '국내': 75, '사장': 75, '코어': 75, '나이': 74, '여자': 74, '더욱': 74, '딜러': 74, '너프': 74, '서울': 73, '사태': 73, '발언': 73, '운영': 73, '재사용': 73, '하자': 72, '순간': 72, '생활': 72, '하위': 72, '채용': 72, '옵션': 72, '방식': 71, '덕분': 71,  ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 불용어 제거

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
# 키워드 데이터에서 불용어를 제거합니다.
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)
# Out:
# Counter({'문단': 1274, '이전': 1097, '역사': 1043, '시즌': 772, '공격': 627, '쿠키': 624, '효과': 521, '강호동': 491, '게임': 484, '사람': 481, '아이템': 462, '토론': 434, '합의': 430, '대한': 423, '이수근': 416, '은지원': 415, '사항': 413, '선수': 392, '시작': 380, '미국': 380, '문제': 363, '피해': 362, '피오': 339, '감독': 338, '미션': 333, '스킬': 325, '기록': 324, '체력': 323, '챔피언': 320, '리그': 311, '국가': 310, '위해': 309, '규현': 308, '송민호': 301, '멤버': 298, '경기': 288, '김정은': 282, '다시': 275, '부분': 275, '페드로': 272, '대통령': 257, '사건': 254, '캐릭터': 251, '드라마': 251, '상태': 249, '마지막': 239, '기본': 239, '가격': 231, '적용': 224, '능력': 222, '상대': 219, '투수': 216, '관련': 213, '마법': 212, '등장': 209, '패치': 209, '호동': 209, '레나': 208, '당시': 208, '속도': 208, '안재현': 208, '현재': 207, '자체': 206, '인간': 202, '종료': 200, '지속': 197, '가지': 193, '중국': 193, '계약': 193, '대해': 192, '출연': 192, '방송': 192, '주문': 190, '일월': 190, '역시': 187, '처음': 181, '대신': 181, '계속': 180, '독일': 180, '북한': 179, '민호': 178, '선택': 177, '대한민국': 176, '조합': 175, '진행': 170, '본인': 168, '다년': 168, '이유': 167, '지원': 167, '바이든': 167, '이닝': 167, '보고': 166, '일본': 166, '치명': 166, '실제': 165, '수준': 162, '사이': 161, '고유': 161, '일부': 160, '시절': 159, '트럼프': 159, '한국': 158, '평가': 158, '우승': 158, '최고': 157, '참고': 157, '결과': 156, '제외': 155, '증가': 154, '헤드': 152, '수근': 151, '열전': 151, '대부분': 149, '일해': 148, '이동': 146, '영상': 145, '정부': 145, '대상': 144, '최대': 144, '방어': 141, '통해': 138, '전쟁': 138, '건담': 138, '공개': 136, '실패': 136, '이야기': 135, '가능성': 135, '지역': 134, '과거': 133, '탈락': 133, '자리': 132, '마드리드': 132, '수도': 131, '후보': 131, '소속': 129, '라운드': 127, '지금': 127, '승리': 127, '먼저': 126, '세계': 126, '유우': 125, '사랑': 124, '늑대': 124, '감소': 124, '기사': 123, '바람': 123, '플레이
# %% [markdown]
# -----

# %% [markdown]
# # <Step3. 시각화> : 워드 클라우드 시각화

# %% [markdown]
# ### [pytagcloud 사용하기]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     - (env_name) `pip install pytagcloud pygame simplejson`
# - 그리고 아래와 같은 경로에 한글 폰트(예: NanumBarunGothic.ttf) 파일을 옮깁니다.
#     - Mac OS : /{anaconda_path}/envs/{env_name}/lib/python3.7/site-packages/pytagcloud/fonts
#     - Windosw OS : \{anaconda_path}\envs\{env_name}\Lib\site-packages\pytagcloud\fonts
#     - `폰트 다운로드 : http://hangeul.naver.com/webfont/NanumGothic/NanumGothic.ttf`
# - 파일을 옮긴 후, 파이썬 가상환경을 재실행 하여 주피터를 다시 실행해줍니다. 그래도 아래의 코드가 실행되지 않는 경우는 다음과 같은 작업을 수행합니다.
#     - 위의 경로에서 font.json 파일을 편집합니다.
#     - 아래와 같은 코드를 추가하고 font.json 파일을 저장합니다.
#     - {
#                 "name": "NanumGothic",
#                 "ttf": "NanumGothic.ttf",
#                 "web": "http://fonts.googleapis.com/css?family=Nanum+Gothic"
#         },

# %%
import random
import pytagcloud
import webbrowser

# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b23e0a6879a8> in <module>
#      10
#      11 # pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
# ---> 12 pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)
#
# c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages\pytagcloud\__init__.py in create_tag_image(tags, output, size, background, layout, fontname, rectangular)
#     338         return
#     339
# --> 340     sizeRect, tag_store = _draw_cloud(tags,
#     341                                       layout,
#     342                                       size=size,
#
# c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages\pytagcloud\__init__.py in _draw_cloud(tag_list, layout, size, fontname, rectangular)
#     273     area = 0
#     274     for tag in tag_list:
# --> 275         tag_sprite = Tag(tag, (0, 0), fontname=fontname)
#     276         area += tag_sprite.mask.count()
#     277         tag_sprites.append(tag_sprite)
#
# c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages\pytagcloud\__init__.py in __init__(self, tag, initial_position, fontname)
#      57         self.rotation = 0
#      58
# ---> 59         self.font_spec = load_font(fontname)
#      60         self.font = font.Font(os.path.join(FONT_DIR,
#      61                                            self.font_spec['ttf']),
#
# c:\users\it-5c\appdata\local\programs\python\python38\lib\site-packages\pytagcloud\__init__.py in load_font(name)
#      99         if font['name'] == name:
#     100             return font
# --> 101     raise AttributeError('Invalid font name. Should be one of %s' %
#     102                          ", ".join([f['name'] for f in FONT_CACHE]))
#     103
#
# AttributeError: Invalid font name. Should be one of Nobile, Old Standard TT, Cantarell, Reenie Beanie, Cuprum, Molengo, Neucha, Philosopher, Yanone Kaffeesatz, Cardo, Neuton, Inconsolata, Crimson Text, Josefin Sans, Droid Sans, Lobster, IM Fell DW Pica, Vollkorn, Tangerine, Coustard, PT Sans Regular

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ### [나무위키 키워드 시각화]

# %% [markdown]
# ##### 제목 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ##### 카테고리 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')
